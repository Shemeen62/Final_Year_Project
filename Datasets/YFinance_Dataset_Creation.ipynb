# %% [markdown]
# # Importing necessary packages

# %%
import yfinance as yf 
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %% [markdown]
# # Retrieving historical data from YFinance

# %%
ticker = yf.Ticker('ORCL')
df = ticker.history(interval='1m', start='2023-07-28', end='2023-07-31')
df.head()
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2023-07-28 09:30:00-04:00  116.680000  116.820000  116.595001  116.750000
# 2023-07-28 09:31:00-04:00  116.779999  116.809998  116.662003  116.769997
# 2023-07-28 09:32:00-04:00  116.809998  116.809998  116.760002  116.760002
# 2023-07-28 09:33:00-04:00  116.800003  116.800003  116.750000  116.750000
# 2023-07-28 09:34:00-04:00  116.779999  116.870003  116.779999  116.839996
#
#                            Volume  Dividends  Stock Splits
# Datetime
# 2023-07-28 09:30:00-04:00   41560        0.0           0.0
# 2023-07-28 09:31:00-04:00    2568        0.0           0.0
# 2023-07-28 09:32:00-04:00    1605        0.0           0.0
# 2023-07-28 09:33:00-04:00     751        0.0           0.0
# 2023-07-28 09:34:00-04:00    1773        0.0           0.0

# %%
df.tail()
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2023-07-28 15:55:00-04:00  116.000000  116.010002  115.879997  115.885002
# 2023-07-28 15:56:00-04:00  115.879997  115.964996  115.875000  115.959999
# 2023-07-28 15:57:00-04:00  115.959999  115.989998  115.940002  115.980003
# 2023-07-28 15:58:00-04:00  115.985001  115.989998  115.955002  115.959999
# 2023-07-28 15:59:00-04:00  115.959999  116.019997  115.949997  116.010002
#
#                            Volume  Dividends  Stock Splits
# Datetime
# 2023-07-28 15:55:00-04:00   31324        0.0           0.0
# 2023-07-28 15:56:00-04:00   69154        0.0           0.0
# 2023-07-28 15:57:00-04:00   37301        0.0           0.0
# 2023-07-28 15:58:00-04:00   56289        0.0           0.0
# 2023-07-28 15:59:00-04:00  221936        0.0           0.0

# %% [markdown]
# # Removing unwanted columns

# %%
columns_to_remove = ['Dividends', 'Stock Splits']
df.drop(columns_to_remove, axis=1, inplace=True)
df.head()

# Reset the index to get the date and time as separate columns
df.reset_index(inplace=True)

# Extract date and time into separate columns
df['Date'] = df['Datetime'].dt.date
df['Time'] = df['Datetime'].dt.time

# Drop the original Datetime column
df.drop('Datetime', axis=1, inplace=True)

# %% [markdown]
# # Extracting data into a CSV

# %%
# Assuming you have a DataFrame called df

# Perform operations on the DataFrame to create new columns (if needed)

# Save the DataFrame to a CSV file
# df.to_csv('ORCL_Data_From_20230703.csv', index=False)

# %%
# # Assuming you have a DataFrame called df with updated values

# # Save the DataFrame to the CSV file in "append" mode
df.to_csv('ORCL_Data_From_20230703.csv', mode='a', index=False, header=False)

# %% [markdown]
# # Reading data from the CSV

# %%
# Read the CSV file and store the data in a DataFrame
df = pd.read_csv('MSFT_Data_From_20230703.csv')

# Display the first few rows of the DataFrame
df.head()
# Out:
#          Open        High         Low       Close   Volume        Date  \
# 0  339.190002  339.649994  338.959991  339.459991  1052335  2023-07-03
# 1  339.459991  339.660004  338.989990  339.649902    92796  2023-07-03
# 2  339.609985  339.850006  339.200012  339.820007    91442  2023-07-03
# 3  339.809998  339.940002  339.339996  339.864990    80170  2023-07-03
# 4  339.829987  339.829987  339.179993  339.260010    91495  2023-07-03
#
#        Time
# 0  09:30:00
# 1  09:31:00
# 2  09:32:00
# 3  09:33:00
# 4  09:34:00
